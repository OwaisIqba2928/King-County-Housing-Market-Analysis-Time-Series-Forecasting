# %% [markdown]
# ### Step 1: Import Libraries

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Load the Dataset

# %%
# Define the file path 
file_path = r"C:\Users\Asus\Music\Advance Analytics & Dashboard Design\kc_house_data.csv"

# %%
# Load the dataset
df = pd.read_csv(file_path)

# %%
# Display first 5 rows
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### Step 3: Check for Missing Values

# %%
# Check for missing values
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ### Step 4: Check Data Types

# %%
# Check data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### Step 5: Remove Duplicates

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates
df = df.drop_duplicates()

# %% [markdown]
# ### Step 6: Summary Statistics

# %%
# Display summary statistics
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ### Step 7: Count Unique Values in Each Column

# %%
# Count unique values per column
df.nunique()
# Out:
# id               21436
# date               372
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %% [markdown]
# ### Step 8: Distribution of House Prices

# %%
# Plot histogram of prices
plt.figure(figsize=(8,5))
plt.hist(df['price'], bins=50, color='blue', edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of House Prices')
plt.show()

# %% [markdown]
# ### Step 9: Bedrooms vs Price

# %%
# Scatter plot of bedrooms vs price
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['bedrooms'], y=df['price'])
plt.xlabel("Number of Bedrooms")
plt.ylabel("Price")
plt.title("Bedrooms vs Price")
plt.show()

# %% [markdown]
# ### Step 10: Square Footage vs Price

# %%
# Scatter plot of sqft_living vs price
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['sqft_living'], y=df['price'])
plt.xlabel("Square Footage of Living Area")
plt.ylabel("Price")
plt.title("Living Space vs Price")
plt.show()

# %% [markdown]
# ### Step 11: Average House Prices Per ZIP Code

# %%
# Group by ZIP code and calculate mean price
zip_prices = df.groupby('zipcode')['price'].mean().sort_values(ascending=False)

# %%
# Display top 10 most expensive ZIP codes
zip_prices.head(10)
# Out:
# zipcode
# 98039    2.160607e+06
# 98004    1.355927e+06
# 98040    1.194230e+06
# 98112    1.095499e+06
# 98102    9.012583e+05
# 98109    8.796236e+05
# 98105    8.628252e+05
# 98006    8.596848e+05
# 98119    8.494480e+05
# 98005    8.101649e+05
# Name: price, dtype: float64

# %% [markdown]
# ### Step 12: Year Built vs Price

# %%
# Scatter plot of year built vs price
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['yr_built'], y=df['price'])
plt.xlabel("Year Built")
plt.ylabel("Price")
plt.title("House Age vs Price")
plt.show()

# %% [markdown]
# ### Step 13: Waterfront vs Non-Waterfront Prices

# %%
# Average price comparison between waterfront and non-waterfront houses
df.groupby('waterfront')['price'].mean()
# Out:
# waterfront
# 0    5.315636e+05
# 1    1.661876e+06
# Name: price, dtype: float64

# %% [markdown]
# ### Step 14: Save Cleaned Dataset

# %%
# Save cleaned dataset
df.to_csv(r"C:\Users\Asus\Music\King_County_Housing_Project\notebooks\cleaned_kc_house_data.csv", index=False)
